# %% [markdown]
# # WeatherPy

# %% [markdown]
# ### Observations and Trends:
#
# * There does not appear to be much correlation seen in the temperature vs. latitude relationship across all cities combined. However, this changes once we separate the data into hemispheres and observe the below.
#
# * There is a strong correlation in the relationship between latitude and max temperature (F) in the northern and southern hemispheres. The northern hemisphere shows a strong negative correlation with temperatures decreasing as you move away from the equator (increasing latitude), while the southern hemisphere shows a strong positive correlation with temperatures increasing as you move towards the equator (increasing latitude).
#
# * There is a trend of higher humidity levels in a majority of cities in the northern hemisphere at this time regardless of distance from the equator, as compared to cities in the southern hemisphere.<br>

# %%
# --- dependencies and setup ---
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
from pprint import pprint

# --- import API key ---
from config import weather_api_key

# --- incorporate citipy to determine city based on latitude and longitude ---
from citipy import citipy

# --- range of latitudes and longitudes ---
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# --- list for holding lat_lngs and cities ---
lat_lngs = []
cities = []

# --- create a set of random lat and lng combinations ---
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# --- identify nearest city for each lat, lng combination ---
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# --- print the city count to confirm sufficient count ---
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# --- fahrenheit units ---
units = "imperial"

# --- build partial query url for API call for fahrenheit data ---
base_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={units}&q="

# --- create empty lists to hold required data ---
city_name = []
city_lats = []
city_lngs = []
city_temp = []
city_maxtemps = []
city_humidity = []
city_cloudiness = []
city_windspeed = []
city_country = []
date = []

# --- initialize count variables for counting city and set ---
item = 1
batch = 1

# --- print initial header before displaying for loop  data ---
print("Beginning Data Retrieval")
print("----------------------------")

# --- for loop go through the list of cities and perform a request for data on each city ---
for city in cities:
    
    # --- build query url with city name ---
    query_url = base_url + city
    
    # --- get the response as json ---
    data = requests.get(query_url).json()
    
    # --- retrieve required data into lists using exception handling ---
    try:
        print(f"Processing Record {item} of Set {batch} | {city}")  
        city_name.append(data["name"])
        city_country.append(data["sys"]["country"])
        city_lats.append(data["coord"]["lat"])
        city_lngs.append(data["coord"]["lon"])    
        city_temp.append(data["main"]["temp"])
        city_maxtemps.append(data["main"]["temp_max"])
        city_humidity.append(data["main"]["humidity"])
        city_cloudiness.append(data["clouds"]["all"])
        city_windspeed.append(data["wind"]["speed"])
        date.append(data["dt"])
        
        # --- increase item count by 1 ---
        item += 1
        
        # --- if statement to limit API calls to 50 using time.sleep (openweathermap API limits calls to 60/minute) ---
        if item > 50:
            # --- start a new set of items ---
            batch += 1
            
            # --- reset item count to 1 for next set ---
            item = 1
            
            # --- delay the execution to stay within the limits of the API query ---
            time.sleep(1)
    
    except:
        print(f"City '{city}' not found. Skipping...")

# --- print completion header after displaying for loop  data ---
print("----------------------------")
print("Data Retrieval Complete")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | clyde river
# Processing Record 2 of Set 1 | upernavik
# Processing Record 3 of Set 1 | kavieng
# Processing Record 4 of Set 1 | norman wells
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | onega
# Processing Record 8 of Set 1 | niquelandia
# Processing Record 9 of Set 1 | cabo san lucas
# Processing Record 10 of Set 1 | lata
# Processing Record 11 of Set 1 | wote
# Processing Record 12 of Set 1 | kamaishi
# Processing Record 13 of Set 1 | turbat
# Processing Record 14 of Set 1 | kovdor
# Processing Record 15 of Set 1 | ukholovo
# Processing Record 16 of Set 1 | vrangel
# Processing Record 17 of Set 1 | esperance
# Processing Record 18 of Set 1 | ribeira grande
# Processing Record 19 of Set 1 | bosaso
# Processing Record 20 of Set 1 | mar del plata
# Processing Record 21 of Set 1 | yining
# Processing Record 22 of Set 1 | samusu
# City 'samusu' not found. Skipping...
# Processing Record 22 of Set 1 | sheltozero
# Processing Record 23 of Set 1 | cidreira
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | qaqortoq
# Processing Record 26 of Set 1 | zaysan
# Processing Record 27 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 1 | hami
# Processing Record 29 of Set 1 | finschhafen
# Processing Record 30 of Set 1 | paamiut
# Processing Record 31 of Set 1 | kaitangata
# Processing Record 32 of Set 1 | kloulklubed
# Processing Record 33 of Set 1 | bustamante
# Processing Record 34 of Set 1 | asau
# Processing Record 35 of Set 1 | klaksvik
# Processing Record 36 of Set 1 | marrakesh
# Processing Record 37 of Set 1 | caravelas
# Processing Record 38 of Set 1 | felanitx
# Processing Record 39 of Set 1 | sao jose da coroa grande
# Processing Record 40 of Set 1 | wana
# Processing Record 41 of Set 1 | sentyabrskiy
# City 'sentyabrskiy' not found. Skipping...
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | khromtau
# Processing Record 43 of Set 1 | kattivakkam
# Processing Record 44 of Set 1 | alofi
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | umzimvubu
# City 'umzimvubu' not found. Skipping...
# Processing Record 46 of Set 1 | elizabeth city
# Processing Record 47 of Set 1 | yarada
# Processing Record 48 of Set 1 | yulara
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | raha
# Processing Record 2 of Set 2 | cayenne
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | leningradskiy
# Processing Record 5 of Set 2 | palana
# Processing Record 6 of Set 2 | nizhneyansk
# City 'nizhneyansk' not found. Skipping...
# Processing Record 6 of Set 2 | port elizabeth
# Processing Record 7 of Set 2 | busselton
# Processing Record 8 of Set 2 | victoria
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | liverpool
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | serebryanyy bor
# Processing Record 13 of Set 2 | illoqqortoormiut
# City 'illoqqortoormiut' not found. Skipping...
# Processing Record 13 of Set 2 | flin flon
# Processing Record 14 of Set 2 | thompson
# Processing Record 15 of Set 2 | labuhan
# Processing Record 16 of Set 2 | bluff
# Processing Record 17 of Set 2 | palmer
# Processing Record 18 of Set 2 | inuvik
# Processing Record 19 of Set 2 | new norfolk
# Processing Record 20 of Set 2 | faanui
# Processing Record 21 of Set 2 | arraial do cabo
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | alice springs
# Processing Record 24 of Set 2 | haines junction
# Processing Record 25 of Set 2 | ayan
# Processing Record 26 of Set 2 | saldanha
# Processing Record 27 of Set 2 | taolanaro
# City 'taolanaro' not found. Skipping...
# Processing Record 27 of Set 2 | roebourne
# Processing Record 28 of Set 2 | east london
# Processing Record 29 of Set 2 | saint george
# Processing Record 30 of Set 2 | ponta do sol
# Processing Record 31 of Set 2 | dobele
# Processing Record 32 of Set 2 | volosovo
# Processing Record 33 of Set 2 | moerai
# Processing Record 34 of Set 2 | frutal
# Processing Record 35 of Set 2 | provideniya
# Processing Record 36 of Set 2 | shira
# Processing Record 37 of Set 2 | anadyr
# Processing Record 38 of Set 2 | punta arenas
# Processing Record 39 of Set 2 | sangar
# Processing Record 40 of Set 2 | hobart
# Processing Record 41 of Set 2 | cordele
# Processing Record 42 of Set 2 | dikson
# Processing Record 43 of Set 2 | lavrentiya
# Processing Record 44 of Set 2 | road town
# Processing Record 45 of Set 2 | vostok
# Processing Record 46 of Set 2 | atuona
# Processing Record 47 of Set 2 | barrow
# Processing Record 48 of Set 2 | louisbourg
# City 'louisbourg' not found. Skipping...
# Processing Record 48 of Set 2 | khatanga
# Processing Record 49 of Set 2 | avera
# Processing Record 50 of Set 2 | lopatyn
# Processing Record 1 of Set 3 | amuntai
# Processing Record 2 of Set 3 | san policarpo
# Processing Record 3 of Set 3 | torbay
# Processing Record 4 of Set 3 | gubkinskiy
# Processing Record 5 of Set 3 | batagay-alyta
# Processing Record 6 of Set 3 | fortuna
# Processing Record 7 of Set 3 | atikokan
# Processing Record 8 of Set 3 | castro
# Processing Record 9 of Set 3 | sao joao da barra
# Processing Record 10 of Set 3 | muroto
# Processing Record 11 of Set 3 | pajapan
# Processing Record 12 of Set 3 | mergui
# City 'mergui' not found. Skipping...
# Processing Record 12 of Set 3 | mezen
# Processing Record 13 of Set 3 | isangel
# Processing Record 14 of Set 3 | kargasok
# Processing Record 15 of Set 3 | marcona
# City 'marcona' not found. Skipping...
# Processing Record 15 of Set 3 | tuktoyaktuk
# Processing Record 16 of Set 3 | omboue
# Processing Record 17 of Set 3 | anthia
# City 'anthia' not found. Skipping...
# Processing Record 17 of Set 3 | kruisfontein
# Processing Record 18 of Set 3 | carnarvon
# Processing Record 19 of Set 3 | baoning
# Processing Record 20 of Set 3 | saskylakh
# Processing Record 21 of Set 3 | port lincoln
# Processing Record 22 of Set 3 | mys shmidta
# City 'mys shmidta' not found. Skipping...
# Processing Record 22 of Set 3 | bethel
# Processing Record 23 of Set 3 | chokurdakh
# Processing Record 24 of Set 3 | altamira
# Processing Record 25 of Set 3 | strezhevoy
# Processing Record 26 of Set 3 | belushya guba
# City 'belushya guba' not found. Skipping...
# Processing Record 26 of Set 3 | pevek
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | acarau
# Processing Record 29 of Set 3 | phangnga
# Processing Record 30 of Set 3 | vestbygda
# City 'vestbygda' not found. Skipping...
# Processing Record 30 of Set 3 | redmond
# Processing Record 31 of Set 3 | acapulco
# Processing Record 32 of Set 3 | chuy
# Processing Record 33 of Set 3 | meadow lake
# Processing Record 34 of Set 3 | soyo
# Processing Record 35 of Set 3 | tiksi
# Processing Record 36 of Set 3 | tuatapere
# Processing Record 37 of Set 3 | geraldton
# Processing Record 38 of Set 3 | ostrovnoy
# Processing Record 39 of Set 3 | west bay
# Processing Record 40 of Set 3 | touros
# Processing Record 41 of Set 3 | kahului
# Processing Record 42 of Set 3 | constitucion
# Processing Record 43 of Set 3 | egvekinot
# Processing Record 44 of Set 3 | port-gentil
# Processing Record 45 of Set 3 | bambous virieux
# Processing Record 46 of Set 3 | benton harbor
# Processing Record 47 of Set 3 | umm lajj
# Processing Record 48 of Set 3 | burgthann
# Processing Record 49 of Set 3 | vaini
# Processing Record 50 of Set 3 | trairi
# Processing Record 1 of Set 4 | tari
# Processing Record 2 of Set 4 | am timan
# Processing Record 3 of Set 4 | nanortalik
# Processing Record 4 of Set 4 | mayo
# Processing Record 5 of Set 4 | boguszow-gorce
# Processing Record 6 of Set 4 | esna
# Processing Record 7 of Set 4 | bulgan
# Processing Record 8 of Set 4 | gondanglegi
# Processing Record 9 of Set 4 | hammerfest
# Processing Record 10 of Set 4 | bathsheba
# Processing Record 11 of Set 4 | nikolskoye
# Processing Record 12 of Set 4 | marsaxlokk
# Processing Record 13 of Set 4 | barentsburg
# City 'barentsburg' not found. Skipping...
# Processing Record 13 of Set 4 | puerto ayora
# Processing Record 14 of Set 4 | ahipara
# Processing Record 15 of Set 4 | nago
# Processing Record 16 of Set 4 | twentynine palms
# Processing Record 17 of Set 4 | raudeberg
# Processing Record 18 of Set 4 | bur gabo
# City 'bur gabo' not found. Skipping...
# Processing Record 18 of Set 4 | udachnyy
# Processing Record 19 of Set 4 | muros
# Processing Record 20 of Set 4 | khormuj
# City 'khormuj' not found. Skipping...
# Processing Record 20 of Set 4 | beihai
# Processing Record 21 of Set 4 | hvammstangi
# City 'hvammstangi' not found. Skipping...
# Processing Record 21 of Set 4 | kamakwie
# Processing Record 22 of Set 4 | necochea
# Processing Record 23 of Set 4 | altay
# Processing Record 24 of Set 4 | arlit
# Processing Record 25 of Set 4 | kodinsk
# Processing Record 26 of Set 4 | juneau
# Processing Record 27 of Set 4 | airai
# Processing Record 28 of Set 4 | kaeo
# Processing Record 29 of Set 4 | jamestown
# Processing Record 30 of Set 4 | flinders
# Processing Record 31 of Set 4 | estevan
# Processing Record 32 of Set 4 | poplar bluff
# Processing Record 33 of Set 4 | deputatskiy
# Processing Record 34 of Set 4 | nioro
# Processing Record 35 of Set 4 | vao
# Processing Record 36 of Set 4 | grand river south east
# City 'grand river south east' not found. Skipping...
# Processing Record 36 of Set 4 | shetpe
# Processing Record 37 of Set 4 | ilembula
# Processing Record 38 of Set 4 | talnakh
# Processing Record 39 of Set 4 | portland
# Processing Record 40 of Set 4 | bandarbeyla
# Processing Record 41 of Set 4 | yellowknife
# Processing Record 42 of Set 4 | george
# Processing Record 43 of Set 4 | grand gaube
# Processing Record 44 of Set 4 | kibuye
# Processing Record 45 of Set 4 | praia
# Processing Record 46 of Set 4 | monrovia
# Processing Record 47 of Set 4 | kapaa
# Processing Record 48 of Set 4 | poum
# Processing Record 49 of Set 4 | pisco
# Processing Record 50 of Set 4 | maningrida
# Processing Record 1 of Set 5 | hajnowka
# Processing Record 2 of Set 5 | kiunga
# Processing Record 3 of Set 5 | kipushi
# Processing Record 4 of Set 5 | aitape
# Processing Record 5 of Set 5 | tazovskiy
# Processing Record 6 of Set 5 | tumannyy
# City 'tumannyy' not found. Skipping...
# Processing Record 6 of Set 5 | serenje
# Processing Record 7 of Set 5 | codrington
# Processing Record 8 of Set 5 | kristiinankaupunki
# Processing Record 9 of Set 5 | galle
# Processing Record 10 of Set 5 | matamoros
# Processing Record 11 of Set 5 | shelburne
# Processing Record 12 of Set 5 | attawapiskat
# City 'attawapiskat' not found. Skipping...
# Processing Record 12 of Set 5 | campos sales
# Processing Record 13 of Set 5 | porvoo
# Processing Record 14 of Set 5 | zhezkazgan
# Processing Record 15 of Set 5 | pahrump
# Processing Record 16 of Set 5 | mnogovershinnyy
# Processing Record 17 of Set 5 | taonan
# Processing Record 18 of Set 5 | amderma
# City 'amderma' not found. Skipping...
# Processing Record 18 of Set 5 | vastervik
# City 'vastervik' not found. Skipping...
# Processing Record 18 of Set 5 | kavaratti
# Processing Record 19 of Set 5 | vestmannaeyjar
# Processing Record 20 of Set 5 | dedovichi
# Processing Record 21 of Set 5 | kodiak
# Processing Record 22 of Set 5 | longyearbyen
# Processing Record 23 of Set 5 | lorengau
# Processing Record 24 of Set 5 | hihifo
# City 'hihifo' not found. Skipping...
# Processing Record 24 of Set 5 | kenai
# Processing Record 25 of Set 5 | zhangjiakou
# Processing Record 26 of Set 5 | puerto colombia
# Processing Record 27 of Set 5 | bejar
# Processing Record 28 of Set 5 | krasnouralsk
# Processing Record 29 of Set 5 | jurado
# Processing Record 30 of Set 5 | los llanos de aridane
# Processing Record 31 of Set 5 | uyuni
# Processing Record 32 of Set 5 | pestera
# Processing Record 33 of Set 5 | abu kamal
# Processing Record 34 of Set 5 | noumea
# Processing Record 35 of Set 5 | arinis
# Processing Record 36 of Set 5 | tasiilaq
# Processing Record 37 of Set 5 | bairiki
# Processing Record 38 of Set 5 | leh
# Processing Record 39 of Set 5 | gurupa
# Processing Record 40 of Set 5 | bengkulu
# Processing Record 41 of Set 5 | darhan
# Processing Record 42 of Set 5 | kang
# Processing Record 43 of Set 5 | miraflores
# Processing Record 44 of Set 5 | raga
# Processing Record 45 of Set 5 | alto vera
# City 'alto vera' not found. Skipping...
# Processing Record 45 of Set 5 | pangnirtung
# Processing Record 46 of Set 5 | henties bay
# Processing Record 47 of Set 5 | ugoofaaru
# Processing Record 48 of Set 5 | meulaboh
# Processing Record 49 of Set 5 | port alfred
# Processing Record 50 of Set 5 | cherskiy
# Processing Record 1 of Set 6 | bloomsburg
# Processing Record 2 of Set 6 | deggendorf
# Processing Record 3 of Set 6 | la rioja
# Processing Record 4 of Set 6 | grand-santi
# Processing Record 5 of Set 6 | beira
# Processing Record 6 of Set 6 | bilibino
# Processing Record 7 of Set 6 | sambava
# Processing Record 8 of Set 6 | hirara
# Processing Record 9 of Set 6 | sredniy ikorets
# Processing Record 10 of Set 6 | lazaro cardenas
# Processing Record 11 of Set 6 | saint anthony
# Processing Record 12 of Set 6 | kayerkan
# Processing Record 13 of Set 6 | formoso do araguaia
# City 'formoso do araguaia' not found. Skipping...
# Processing Record 13 of Set 6 | coahuayana
# Processing Record 14 of Set 6 | swan hill
# Processing Record 15 of Set 6 | bam
# Processing Record 16 of Set 6 | niquero
# Processing Record 17 of Set 6 | blackwater
# Processing Record 18 of Set 6 | mikhaylovka
# Processing Record 19 of Set 6 | oranjemund
# Processing Record 20 of Set 6 | souillac
# Processing Record 21 of Set 6 | yar-sale
# Processing Record 22 of Set 6 | vanimo
# Processing Record 23 of Set 6 | corinto
# Processing Record 24 of Set 6 | severo-kurilsk
# Processing Record 25 of Set 6 | sitka
# Processing Record 26 of Set 6 | lebu
# Processing Record 27 of Set 6 | padang
# Processing Record 28 of Set 6 | ormara
# Processing Record 29 of Set 6 | zabol
# Processing Record 30 of Set 6 | baie-comeau
# Processing Record 31 of Set 6 | seoul
# Processing Record 32 of Set 6 | ulaanbaatar
# Processing Record 33 of Set 6 | udaipura
# Processing Record 34 of Set 6 | toamasina
# Processing Record 35 of Set 6 | luderitz
# Processing Record 36 of Set 6 | fairhope
# Processing Record 37 of Set 6 | faya
# Processing Record 38 of Set 6 | birao
# Processing Record 39 of Set 6 | boende
# Processing Record 40 of Set 6 | lucapa
# Processing Record 41 of Set 6 | belaya gora
# Processing Record 42 of Set 6 | olafsvik
# Processing Record 43 of Set 6 | santiago de cuba
# Processing Record 44 of Set 6 | harper
# Processing Record 45 of Set 6 | lagoa
# Processing Record 46 of Set 6 | bay-khaak
# Processing Record 47 of Set 6 | belyy yar
# Processing Record 48 of Set 6 | bonavista
# Processing Record 49 of Set 6 | jutai
# Processing Record 50 of Set 6 | fort nelson
# Processing Record 1 of Set 7 | lalibela
# Processing Record 2 of Set 7 | manadhoo
# Processing Record 3 of Set 7 | saint-philippe
# Processing Record 4 of Set 7 | suntar
# Processing Record 5 of Set 7 | bolshoy tsaryn
# City 'bolshoy tsaryn' not found. Skipping...
# Processing Record 5 of Set 7 | kiskore
# Processing Record 6 of Set 7 | nova borova
# Processing Record 7 of Set 7 | atar
# Processing Record 8 of Set 7 | gamba
# Processing Record 9 of Set 7 | marsh harbour
# Processing Record 10 of Set 7 | masinloc
# Processing Record 11 of Set 7 | jiangyou
# Processing Record 12 of Set 7 | hofn
# Processing Record 13 of Set 7 | rio grande
# Processing Record 14 of Set 7 | puerto escondido
# Processing Record 15 of Set 7 | merauke
# Processing Record 16 of Set 7 | poykovskiy
# Processing Record 17 of Set 7 | tondano
# Processing Record 18 of Set 7 | praya
# Processing Record 19 of Set 7 | moussoro
# Processing Record 20 of Set 7 | cherepovets
# Processing Record 21 of Set 7 | dudinka
# Processing Record 22 of Set 7 | port macquarie
# Processing Record 23 of Set 7 | izhma
# Processing Record 24 of Set 7 | wanxian
# Processing Record 25 of Set 7 | leshukonskoye
# Processing Record 26 of Set 7 | kungurtug
# Processing Record 27 of Set 7 | samarinda
# Processing Record 28 of Set 7 | saleaula
# City 'saleaula' not found. Skipping...
# Processing Record 28 of Set 7 | linhai
# Processing Record 29 of Set 7 | gambela
# Processing Record 30 of Set 7 | iqaluit
# Processing Record 31 of Set 7 | bahraich
# Processing Record 32 of Set 7 | tarudant
# City 'tarudant' not found. Skipping...
# Processing Record 32 of Set 7 | tarpon springs
# Processing Record 33 of Set 7 | anar darreh
# City 'anar darreh' not found. Skipping...
# Processing Record 33 of Set 7 | zambezi
# Processing Record 34 of Set 7 | ixtapa
# Processing Record 35 of Set 7 | buchmany
# Processing Record 36 of Set 7 | utiroa
# City 'utiroa' not found. Skipping...
# Processing Record 36 of Set 7 | nsanje
# Processing Record 37 of Set 7 | matagami
# Processing Record 38 of Set 7 | srednekolymsk
# Processing Record 39 of Set 7 | plettenberg bay
# Processing Record 40 of Set 7 | ca mau
# Processing Record 41 of Set 7 | georgetown
# Processing Record 42 of Set 7 | gongzhuling
# Processing Record 43 of Set 7 | moses lake
# Processing Record 44 of Set 7 | dingle
# Processing Record 45 of Set 7 | artvin
# Processing Record 46 of Set 7 | shu
# Processing Record 47 of Set 7 | waddan
# Processing Record 48 of Set 7 | hasaki
# Processing Record 49 of Set 7 | manzil tamim
# City 'manzil tamim' not found. Skipping...
# Processing Record 49 of Set 7 | trincomalee
# Processing Record 50 of Set 7 | porto santo
# Processing Record 1 of Set 8 | iturama
# Processing Record 2 of Set 8 | mahebourg
# Processing Record 3 of Set 8 | beringovskiy
# Processing Record 4 of Set 8 | kamenskoye
# City 'kamenskoye' not found. Skipping...
# Processing Record 4 of Set 8 | apricena
# Processing Record 5 of Set 8 | bud
# Processing Record 6 of Set 8 | san carlos
# Processing Record 7 of Set 8 | seymchan
# Processing Record 8 of Set 8 | aflu
# City 'aflu' not found. Skipping...
# Processing Record 8 of Set 8 | katobu
# Processing Record 9 of Set 8 | bonthe
# Processing Record 10 of Set 8 | bembereke
# Processing Record 11 of Set 8 | tessalit
# Processing Record 12 of Set 8 | tigil
# Processing Record 13 of Set 8 | korla
# Processing Record 14 of Set 8 | carberry
# Processing Record 15 of Set 8 | saint-pierre
# Processing Record 16 of Set 8 | komsomolskiy
# Processing Record 17 of Set 8 | taihe
# Processing Record 18 of Set 8 | manaus
# Processing Record 19 of Set 8 | vila velha
# Processing Record 20 of Set 8 | golden
# Processing Record 21 of Set 8 | winsum
# Processing Record 22 of Set 8 | mabaruma
# Processing Record 23 of Set 8 | houma
# Processing Record 24 of Set 8 | apac
# Processing Record 25 of Set 8 | sao filipe
# Processing Record 26 of Set 8 | shiraz
# Processing Record 27 of Set 8 | port pirie
# Processing Record 28 of Set 8 | ambilobe
# Processing Record 29 of Set 8 | myaundzha
# Processing Record 30 of Set 8 | taketa
# Processing Record 31 of Set 8 | bilma
# Processing Record 32 of Set 8 | tsihombe
# City 'tsihombe' not found. Skipping...
# Processing Record 32 of Set 8 | hambantota
# Processing Record 33 of Set 8 | marawi
# Processing Record 34 of Set 8 | ayacucho
# Processing Record 35 of Set 8 | atlantic city
# Processing Record 36 of Set 8 | vila do maio
# Processing Record 37 of Set 8 | cartagena
# Processing Record 38 of Set 8 | coquimbo
# Processing Record 39 of Set 8 | nhulunbuy
# Processing Record 40 of Set 8 | mincivan
# Processing Record 41 of Set 8 | ola
# Processing Record 42 of Set 8 | westport
# Processing Record 43 of Set 8 | bocos
# Processing Record 44 of Set 8 | sciacca
# Processing Record 45 of Set 8 | vaitupu
# City 'vaitupu' not found. Skipping...
# Processing Record 45 of Set 8 | hassan
# Processing Record 46 of Set 8 | narsaq
# Processing Record 47 of Set 8 | kawalu
# Processing Record 48 of Set 8 | berlevag
# Processing Record 49 of Set 8 | te anau
# Processing Record 50 of Set 8 | aksay
# Processing Record 1 of Set 9 | santa isabel do rio negro
# Processing Record 2 of Set 9 | sogdiondon
# City 'sogdiondon' not found. Skipping...
# Processing Record 2 of Set 9 | pital
# Processing Record 3 of Set 9 | kodinar
# Processing Record 4 of Set 9 | ancud
# Processing Record 5 of Set 9 | wagar
# Processing Record 6 of Set 9 | mahibadhoo
# Processing Record 7 of Set 9 | banda aceh
# Processing Record 8 of Set 9 | mosquera
# Processing Record 9 of Set 9 | cortez
# Processing Record 10 of Set 9 | kangaatsiaq
# Processing Record 11 of Set 9 | ponta delgada
# Processing Record 12 of Set 9 | kano
# Processing Record 13 of Set 9 | izumo
# Processing Record 14 of Set 9 | chernyshevskiy
# Processing Record 15 of Set 9 | bend
# Processing Record 16 of Set 9 | mount gambier
# Processing Record 17 of Set 9 | rungata
# City 'rungata' not found. Skipping...
# Processing Record 17 of Set 9 | anastacio
# Processing Record 18 of Set 9 | santa rosalia
# Processing Record 19 of Set 9 | mairwa
# Processing Record 20 of Set 9 | hovd
# Processing Record 21 of Set 9 | kirakira
# Processing Record 22 of Set 9 | san carlos de bariloche
# Processing Record 23 of Set 9 | cap malheureux
# Processing Record 24 of Set 9 | sao miguel do araguaia
# Processing Record 25 of Set 9 | namatanai
# Processing Record 26 of Set 9 | urdzhar
# City 'urdzhar' not found. Skipping...
# Processing Record 26 of Set 9 | hervey bay
# Processing Record 27 of Set 9 | gumdag
# Processing Record 28 of Set 9 | limbuhan
# Processing Record 29 of Set 9 | middle island
# Processing Record 30 of Set 9 | margate
# Processing Record 31 of Set 9 | ust-tsilma
# Processing Record 32 of Set 9 | salalah
# Processing Record 33 of Set 9 | san ramon
# Processing Record 34 of Set 9 | talcahuano
# Processing Record 35 of Set 9 | tautira
# Processing Record 36 of Set 9 | college
# Processing Record 37 of Set 9 | tarakan
# Processing Record 38 of Set 9 | qinzhou
# Processing Record 39 of Set 9 | irbil
# Processing Record 40 of Set 9 | yenagoa
# Processing Record 41 of Set 9 | kyra
# Processing Record 42 of Set 9 | haibowan
# City 'haibowan' not found. Skipping...
# Processing Record 42 of Set 9 | trinidad
# Processing Record 43 of Set 9 | yirol
# City 'yirol' not found. Skipping...
# Processing Record 43 of Set 9 | wulanhaote
# City 'wulanhaote' not found. Skipping...
# Processing Record 43 of Set 9 | la ronge
# Processing Record 44 of Set 9 | sol-iletsk
# Processing Record 45 of Set 9 | praia da vitoria
# Processing Record 46 of Set 9 | auki
# Processing Record 47 of Set 9 | santo augusto
# Processing Record 48 of Set 9 | gualaquiza
# Processing Record 49 of Set 9 | najran
# Processing Record 50 of Set 9 | susanville
# Processing Record 1 of Set 10 | taos
# Processing Record 2 of Set 10 | rundu
# Processing Record 3 of Set 10 | north bend
# Processing Record 4 of Set 10 | dzhusaly
# City 'dzhusaly' not found. Skipping...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# --- create a dataframe with retrieved data ---
cities_temps_df = pd.DataFrame({"City": city_name,
                                "Country": city_country,
                                "Date": date,
                                "Lat": city_lats,
                                "Lng": city_lngs,
                                "Max Temp (F)": city_maxtemps,
                                "Humidity (%)": city_humidity,
                                "Cloudiness (%)": city_cloudiness,
                                "Wind Speed (mph)": city_windspeed,
                                })

# --- convert unix timestamp under date column to date,time using pd.to_datetime ---
cities_temps_df["Date"] = pd.to_datetime(cities_temps_df["Date"], unit = "s")

# --- save the dataframe to .csv file ---
cities_temps_df.to_csv("../output_data/cities.csv", index=True, index_label="City ID", header=True)

# --- display the dataframe ---
cities_temps_df

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# --- find cities that have humidity over 100% ---
humidity_over_100 = cities_temps_df.loc[cities_temps_df["Humidity (%)"] > 100, :]

if humidity_over_100.empty == True:
    print("There are no cities with humidity values over 100%")
    print("Using original dataframe to continue with plotting...")
    
    # --- extract relevant fields from the data frame for plotting ---
    latitudes = cities_temps_df["Lat"]
    temperatures = cities_temps_df["Max Temp (F)"]
    humidity = cities_temps_df["Humidity (%)"]
    cloudiness = cities_temps_df["Cloudiness (%)"]
    windspeed = cities_temps_df["Wind Speed (mph)"]
    
else:
    # -- get the indices of cities that have humidity over 100% ---
    Humidityover100Index = humidity_over_100.index
    
    # --- create a clean DataFrame by dropping all humidity outliers by index found above ---
    clean_city_data = cities_temps_df.drop(Humidityover100Index).reset_index(drop=True)
    clean_city_data.head()
    
    # --- extract relevant fields from the data frame for plotting ---
    latitudes = clean_city_data["Lat"]
    temperatures = clean_city_data["Max Temp (F)"]
    humidity = clean_city_data["Humidity (%)"]
    cloudiness = clean_city_data["Cloudiness (%)"]
    windspeed = clean_city_data["Wind Speed (mph)"]

    # --- export the new dataframe into a csv ---
    clean_city_data.to_csv("../output_data/clean_city_data.csv", index=True, index_label="City ID", header=True)
# Out:
# There are no cities with humidity values over 100%
# Using original dataframe to continue with plotting...

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# --- create a scatter plot depicting latitude vs temperature ---

plt.scatter(latitudes, temperatures, marker="o", facecolors="lightsalmon", edgecolors="sienna")

# --- add labels, title, limits & grid ---
plt.title("City Latitude vs. Max Temperature (19/06/20)", fontsize=14)
plt.ylabel("Max Temperature (F)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.grid()

# --- display and save the plot ---
plt.savefig("../Images/latitude-vs-temp.png")
plt.show()

# %% [markdown]
# ### Temperature (F) vs. Latitude
# The scatterplot for Temperature (F) vs. Latitude above shows that the temperatures tend to be higher near the equator (0 degrees latitude) at this time.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# --- create a scatter plot depicting latitude vs humidity ---
plt.scatter(latitudes, humidity, marker="o", facecolors="lightsalmon", edgecolors="sienna")

# --- add labels, title, limits & grid ---
plt.title("City Latitude vs. Humidity (19/06/20)", fontsize=14)
plt.ylabel("Humidity (%)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.grid()

# --- display and save the plot ---
plt.savefig("../Images/latitude-vs-humidity.png")
plt.show()

# %% [markdown]
# ### Humidity (%) vs. Latitude
# The scatterplot for Humidity (%) vs. Latitude above does not appear to have much correlation. From the data points visualized, we can see that a large number of cities seem to have high humidity levels currently, with the majority being near the equator or in the northern hemisphere.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# --- create a scatter plot depicting latitude vs cloudiness ---
plt.scatter(latitudes, cloudiness, marker="o", facecolors="lightsalmon", edgecolors="sienna")

# --- add labels, title, limits & grid ---
plt.title("City Latitude vs. Cloudiness (19/06/20)", fontsize=14)
plt.ylabel("Cloudiness (%)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.grid()

# --- display and save the plot ---
plt.savefig("../Images/latitude-vs-cloudiness.png")
plt.show()

# %% [markdown]
# ### Cloudiness (%) vs. Latitude
# The scatterplot for Cloudiness (%) vs. Latitude above also does not appear to have much correlation, like humidity.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# --- create a scatter plot depicting latitude vs wind speed ---
plt.scatter(latitudes, windspeed, marker="o", facecolors="lightsalmon", edgecolors="sienna")

# --- add labels, title, limits & grid ---
plt.title("City Latitude vs. Windspeed (19/06/20)", fontsize=14)
plt.ylabel("Windspeed (mph)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.grid()

# --- display and save the plot ---
plt.savefig("../Images/latitude-vs-windspeed.png")
plt.show()

# %% [markdown]
# ### Wind Speed (mph) vs. Latitude
# The scatterplot for Wind Speed (mph) vs. Latitude again, does not show correlation, like humidity and cloudiness. It is observed that wind speeds are generally low at this time.

# %% [markdown]
# ## Linear Regression

# %%
#*******************************************************
# Create a function to create Linear Regression plots
#*******************************************************

def plot_linear_regression(x, y, ax=None, **kwargs):
    
    # --- use the axes specified ---
    ax = ax
    
    # --- get linear regression values and store in variables ---
    slope, intercept, rvalue, pvalue, stderror = linregress(x,y)
    print(f"Linear Regression Completed...")    
    print(f"The R Squared is: {rvalue**2}")

    # y = m * x + b
    regress_values = slope * x + intercept
    
    # --- create line equation ---
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
                                                          
    # --- plot the linear model ---
    ax.plot(x, regress_values, color="firebrick")
    
    # --- return the plot and line equation created ---
    return ax, line_eq

# %%
#*****************************************************
# Create Northern and Southern Hemisphere DataFrames
#*****************************************************

# --- find and store rows for Northern Hemisphere dataframe (greater than or equal to 0 degrees latitude) --- 
if humidity_over_100.empty == True:
    northern_hemisphere = cities_temps_df.loc[cities_temps_df["Lat"] >= 0, :].copy().reset_index(drop=True)
else:
    northern_hemisphere = clean_city_data.loc[clean_city_data["Lat"] >= 0, :].copy().reset_index(drop=True)
    

# --- find and store rows for Southern Hemisphere dataframe (less than 0 degrees latitude) ---
if humidity_over_100.empty == True:
    southern_hemisphere = cities_temps_df.loc[cities_temps_df["Lat"] < 0, :].copy().reset_index(drop=True)
else:
    southern_hemisphere = clean_city_data.loc[clean_city_data["Lat"] < 0, :].copy().reset_index(drop=True)    

# --- extract relevant fields from both data frames for plotting ---
north_latitudes = northern_hemisphere["Lat"]
north_temperatures = northern_hemisphere["Max Temp (F)"]
north_humidity = northern_hemisphere["Humidity (%)"]
north_cloudiness = northern_hemisphere["Cloudiness (%)"]
north_windspeed = northern_hemisphere["Wind Speed (mph)"]

south_latitudes = southern_hemisphere["Lat"]
south_temperatures = southern_hemisphere["Max Temp (F)"]
south_humidity = southern_hemisphere["Humidity (%)"]
south_cloudiness = southern_hemisphere["Cloudiness (%)"]
south_windspeed = southern_hemisphere["Wind Speed (mph)"]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#**********************************************************************************
# Run linear regression on Northern Hemisphere - Temperature (F) vs. Latitude
#**********************************************************************************

# --- create scatter plot ---
fig, ax = plt.subplots(figsize = (8,6))
plt.scatter(north_latitudes, north_temperatures, marker="o", facecolors="aquamarine", edgecolors="darkcyan")

# --- call linear regression plot function to retrieve plot and line equation (for annotation) ---
ax, line_eq = plot_linear_regression(north_latitudes, north_temperatures, ax)

# --- add labels, title, limits & grid ---
plt.title("City Latitude vs. Max Temperature in the Northern Hemisphere (19/06/20)", fontsize=14)
plt.ylabel("Max Temperature (F)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.grid()

# --- annotate the linear regression line equation on the plot ---
plt.annotate(line_eq,(5,45),fontsize=16,color="firebrick")

# --- display and save the plot ---
plt.savefig("../Images/northern-latitude-vs-temp-linreg.png")
plt.show()
# Out:
# Linear Regression Completed...
# The R Squared is: 0.7302721366359707

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#**********************************************************************************
# Run linear regression on Southern Hemisphere - Temperature (F) vs. Latitude
#**********************************************************************************

# --- create scatter plot ---
fig, ax = plt.subplots(figsize = (8,6))
plt.scatter(south_latitudes, south_temperatures, marker="o", facecolors="gold", edgecolors="darkgoldenrod")

# --- call linear regression plot function to retrieve plot and line equation (for annotation) ---
ax, line_eq = plot_linear_regression(south_latitudes, south_temperatures, ax)

# --- add labels, title, limits & grid ---
plt.title("City Latitude vs. Max Temperature in the Southern Hemisphere (19/06/20)", fontsize=14)
plt.ylabel("Max Temperature (F)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.grid()

# --- annotate the linear regression line equation on the plot ---
plt.annotate(line_eq,(-25, 35),fontsize=16,color="firebrick")

# --- display and save the plot ---
plt.savefig("../Images/southern-latitude-vs-temp-linreg.png")
plt.show()
# Out:
# Linear Regression Completed...
# The R Squared is: 0.5047443856037368

# %% [markdown]
# ### Northern/Southern Hemispheres - Temperature (F) vs. Latitude Linear Regression
# Both scatter plots show a strong correlation between max temperature (F) and latitude, with the northern hemisphere displaying a negative correlation and the southern hemisphere being positive.
#
# Looking at this pair of plots, it is apparent that temperatures are higher as you near the equator (0 degrees latitude). In the northern hemisphere, we see temperature falling as latitude increases, and in the southern hemisphere, temperatures increase while latitude increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#**********************************************************************************
# Run linear regression on Northern Hemisphere - Humidity (%) vs. Latitude
#**********************************************************************************

# --- create scatter plot ---
fig, ax = plt.subplots(figsize = (8,6))
plt.scatter(north_latitudes, north_humidity, marker="o", facecolors="aquamarine", edgecolors="darkcyan")

# --- call linear regression plot function to retrieve plot and line equation (for annotation) ---
ax, line_eq = plot_linear_regression(north_latitudes, north_humidity, ax)

# --- add labels, title, limits & grid ---
plt.title("City Latitude vs. Humidity in the Northern Hemisphere (19/06/20)", fontsize=14)
plt.ylabel("Humidity (%)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.grid()

# --- annotate the linear regression line equation on the plot ---
plt.annotate(line_eq,(50,10),fontsize=16,color="firebrick")

# --- display and save the plot ---
plt.savefig("../Images/northern-latitude-vs-humidity-linreg.png")
plt.show()
# Out:
# Linear Regression Completed...
# The R Squared is: 0.04332600534853997

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#**********************************************************************************
# Run linear regression on Southern Hemisphere - Humidity (%) vs. Latitude
#**********************************************************************************

# --- create scatter plot ---
fig, ax = plt.subplots(figsize = (8,6))
plt.scatter(south_latitudes, south_humidity, marker="o", facecolors="gold", edgecolors="darkgoldenrod")

# --- call linear regression plot function to retrieve plot and line equation (for annotation) ---
ax, line_eq = plot_linear_regression(south_latitudes, south_humidity, ax)

# --- add labels, title, limits & grid ---
plt.title("City Latitude vs. Humidity in the Southern Hemisphere (19/06/20)", fontsize=14)
plt.ylabel("Humidity (%)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.grid()

# --- annotate the linear regression line equation on the plot ---
plt.annotate(line_eq,(-55, 25),fontsize=16,color="firebrick")

# --- display and save the plot ---
plt.savefig("../Images/southern-latitude-vs-humidity-linreg.png")
plt.show()
# Out:
# Linear Regression Completed...
# The R Squared is: 0.008193191769843275

# %% [markdown]
# ### Northern/Southern Hemispheres - Humidity (%) vs. Latitude Linear Regression
# There does not appear to be any correlation between humidity and latitude in both the northern and southern hemispheres.
#
# Considering it is summer time, the cities in the northern hemisphere seem to be displaying a general trend of higher humidity levels regardless of distance from the equator.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#************************************************************************************
# Run linear regression on Northern Hemisphere - Cloudiness (%) vs. Latitude 
#************************************************************************************

# --- create scatter plot ---
fig, ax = plt.subplots(figsize = (8,6))
plt.scatter(north_latitudes, north_cloudiness, marker="o", facecolors="aquamarine", edgecolors="darkcyan")

# --- call linear regression plot function to retrieve plot and line equation (for annotation) ---
ax, line_eq = plot_linear_regression(north_latitudes, north_cloudiness, ax)

# --- add labels, title, limits & grid ---
plt.title("City Latitude vs. Cloudiness in the Northern Hemisphere (19/06/20)", fontsize=14)
plt.ylabel("Cloudiness (%)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.grid()

# --- annotate the linear regression line equation on the plot ---
plt.annotate(line_eq,(1,10),fontsize=16,color="firebrick")

# --- display and save the plot ---
plt.savefig("../Images/northern-latitude-vs-cloudiness-linreg.png")
plt.show()
# Out:
# Linear Regression Completed...
# The R Squared is: 0.025222926855323593

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#************************************************************************************
# Run linear regression on Southern Hemisphere - Cloudiness (%) vs. Latitude
#************************************************************************************

# --- create scatter plot ---
fig, ax = plt.subplots(figsize = (8,6))
plt.scatter(south_latitudes, south_cloudiness, marker="o", facecolors="gold", edgecolors="darkgoldenrod")

# --- call linear regression plot function to retrieve plot and line equation (for annotation) ---
ax, line_eq = plot_linear_regression(south_latitudes, south_cloudiness, ax)

# --- add labels, title, limits & grid ---
plt.title("City Latitude vs. Cloudiness in the Southern Hemisphere (19/06/20)", fontsize=14)
plt.ylabel("Humidity (%)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.grid()

# --- annotate the linear regression line equation on the plot ---
plt.annotate(line_eq,(-55, 25),fontsize=16,color="firebrick")

# --- display and save the plot ---
plt.savefig("../Images/southern-latitude-vs-cloudiness-linreg.png")
plt.show()
# Out:
# Linear Regression Completed...
# The R Squared is: 0.01618180050210923

# %% [markdown]
# ### Northern/Southern Hemispheres - Cloudiness (%) vs. Latitude Linear Regression
# There does not appear to be any correlation between cloud cover and latitude in both the northern and southern hemispheres.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#************************************************************************************
# Run linear regression on Northern Hemisphere - Wind Speed (mph) vs. Latitude
#************************************************************************************

# --- create scatter plot ---
fig, ax = plt.subplots(figsize = (8,6))
plt.scatter(north_latitudes, north_windspeed, marker="o", facecolors="aquamarine", edgecolors="darkcyan")

# --- call linear regression plot function to retrieve plot and line equation (for annotation) ---
ax, line_eq = plot_linear_regression(north_latitudes, north_windspeed, ax)

# --- add labels, title, limits & grid ---
plt.title("City Latitude vs. Wind Speed in the Northern Hemisphere (19/06/20)", fontsize=14)
plt.ylabel("Wind Speed (mph)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.grid()

# --- annotate the linear regression line equation on the plot ---
plt.annotate(line_eq,(5,26),fontsize=16,color="firebrick")

# --- display and save the plot ---
plt.savefig("../Images/northern-latitude-vs-windspeed-linreg.png")
plt.show()
# Out:
# Linear Regression Completed...
# The R Squared is: 0.02051159981657034

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#************************************************************************************
# Run linear regression on Southern Hemisphere - Wind Speed (mph) vs. Latitude 
#************************************************************************************

# --- create scatter plot ---
fig, ax = plt.subplots(figsize = (8,6))
plt.scatter(south_latitudes, south_windspeed, marker="o", facecolors="gold", edgecolors="darkgoldenrod")

# --- call linear regression plot function to retrieve plot and line equation (for annotation) ---
ax, line_eq = plot_linear_regression(south_latitudes, south_windspeed, ax)

# --- add labels, title, limits & grid ---
plt.title("City Latitude vs. Wind Speed in the Southern Hemisphere (19/06/20)", fontsize=14)
plt.ylabel("Wind Speed (mph)", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.grid()

# --- annotate the linear regression line equation on the plot ---
plt.annotate(line_eq,(-55, 20),fontsize=16,color="firebrick")

# --- display and save the plot ---
plt.savefig("../Images/southern-latitude-vs-windspeed-linreg.png")
plt.show()
# Out:
# Linear Regression Completed...
# The R Squared is: 0.017410796036760746

# %% [markdown]
# ### Northern/Southern Hemispheres - Wind Speed mph vs. Latitude Linear Regression
# There does not appear to be any correlation between wind speed and latitude in both the northern and southern hemispheres.
